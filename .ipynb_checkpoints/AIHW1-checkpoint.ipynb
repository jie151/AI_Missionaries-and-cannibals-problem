# %%
import queue
import numpy as np
import prettytable as pt

#rightM = int(input("請輸入傳教士的人數: ")) #右岸的傳教士要送到左岸
#rightC = int(input("請輸入野人的人數: "))  # 右岸的野人要送到左岸
rightM = 3 #右岸的傳教士人數
rightC = 3 #左岸的傳教士人數
bAMax = 2 #boat a 最多可載2人
bBMax = 3 #boat b 最多可載3人
bACost = 3  #一趟的花費
bBCost = 25 #一趟的花費
bATime = 1
bBTime = 1 
bAPos = 1 #初始在右岸
bBPos = 1 #初始在右岸
costOrTime = 0 #cost:0, time:1

class Node:
    def __init__(self, m, c, bA_pos, bA_move, bA_m, bA_c, bB_pos, bB_move, bB_m, bB_c, step, cost, parent):
        self.m = m    # m:右岸的傳教士数量
        self.c = c    # c:右岸野人数量
        self.bA_m = bA_m #boat A 傳教士的人數
        self.bA_c = bA_c #boat A 野人的人數
        self.bB_m = bB_m #boat B 傳教士的人數
        self.bB_c = bB_c #obat B 野人的人數
        self.bA = bA_pos  # bA:船的位置，右岸: 1 (右 -> 左), 左岸:0 (左 -> 右)
        self.bB = bB_pos  # bB:船的位置，右岸: 1, 左岸:0
        self.bAMove = bA_move # moving: 1
        self.bBMove = bB_move # moving: 1
        self.step = step # step數
        self.cost = cost # 成本
        #self.h = m + c - Ka * ba * ba_move - Kb * bB * bb_move #評估值
        self.parent = parent

def is_safe(right_m, right_c):
    m = right_m
    c = right_c
    leftM = rightM - m
    leftC = rightC - c
    if (m < c and m!= 0): #右岸野人人數不能大於傳教士，除非傳教士為0
        return False
    if (leftM < leftC) and m != rightM: #左岸的野人人數不能大於傳教士，除非左岸傳教士為0
        return False
    if (m < 0 or c < 0): #人數不能小於0
        return False
    if (m >= c and leftM >= leftC):
        return True
def boatA_actions (bAMax, bAcost, bAtime):
    set_boatA_operation = [] 
    for i in range (bAMax + 1):
        if (i == 0): #船上只有野人
            for j in range(1, bAMax + 1):  
                set_boatA_operation.append([i, j, bAcost, bAtime])
        else: #船上有傳教士
            for j in range (0, i + 1):
                if i + j <= bAMax and (i != 0): 
                    set_boatA_operation.append([i, j, bAcost, bAtime]) 
    print("boatA所有動作為: ", set_boatA_operation)
    return set_boatA_operation

def boatB_actions (bBMax, bBcost, bBtime):
    set_boatB_operation = [] 
    for i in range (bBMax + 1):
        if (i == 0): #船上只有野人
            for j in range(1, bBMax + 1):
                set_boatB_operation.append([i, j, bBcost, bBtime])
        else: #船上有傳教士
            for j in range (0, i + 1):
                if i + j <= bBMax and (i != 0):
                    set_boatB_operation.append([i, j, bBcost, bBtime])
    print("boatB所有動作為: ", set_boatB_operation)
    return set_boatB_operation

boatA_operations = boatA_actions(2, bACost, bATime)
boatB_operations = boatB_actions(3, bBCost, bBTime)


def find_move_Cost(curr_node, cost_or_time, boatA_operations, boatB_operations):
    successor = []
    right_m = curr_node.m
    right_c = curr_node.c
    left_m = rightM - right_m
    left_c = rightC - right_c
   
    if (curr_node.bAPos): 
        for boatA_operation in boatA_operations:
            print("boatA_operation: ", boatA_operation)
            right_m_bA = right_m - boatA_operation[0]
            right_c_bA = right_c - boatA_operation[1]
            if is_safe(right_m_bA, right_c_bA):
                if (curr_node.bBPos):
                    for boatB_operation in boatB_operations:
                        print("boatB_operation: ", boatB_operation)
                        right_m_bB = right_m_bA -  boatB_operation[0]
                        right_c_bB = right_c_bA -  boatB_operation[1]
                        if is_safe(right_m_bB, right_c_bB):
                            successor.append(Node(right_m_bB, right_c_bB, -curr_node.bAPos, 1, ))


def UCS (start_node, boatA_operation, boatB_operation):
    openList = queue.Queue() #open list
    openList.put(start_node) 
    print("hi!")
    #while 1:
    if (openList.empty()):
        print("失敗!open list 為空，不存在有可用的節點")
        return
    vertex = openList.get()
    print("hi vertex", vertex.state)
# Out:
# boatA所有動作為:  [[0, 1, 3, 1], [0, 2, 3, 1], [1, 0, 3, 1], [1, 1, 3, 1], [2, 0, 3, 1]]
# boatB所有動作為:  [[0, 1, 25, 1], [0, 2, 25, 1], [0, 3, 25, 1], [1, 0, 25, 1], [1, 1, 25, 1], [2, 0, 25, 1], [2, 1, 25, 1], [3, 0, 25, 1]]

# %%
import queue
import numpy as np
import prettytable as pt

#rightM = int(input("請輸入傳教士的人數: ")) #右岸的傳教士要送到左岸
#rightC = int(input("請輸入野人的人數: "))  # 右岸的野人要送到左岸
rightM = 3 #右岸的傳教士人數
rightC = 3 #左岸的傳教士人數
bAMax = 2 #boat a 最多可載2人
bBMax = 3 #boat b 最多可載3人
bACost = 3  #一趟的花費
bBCost = 25 #一趟的花費
bATime = 1
bBTime = 1 
bAPos = 1 #初始在右岸
bBPos = 1 #初始在右岸 
costOrTime = 0 #cost:0, time:1

class Node:
    def __init__(self, m, c, bA_pos, bA_move, bA_m, bA_c, bB_pos, bB_move, bB_m, bB_c, step, cost, parent):
        self.m = m    # m:右岸的傳教士数量
        self.c = c    # c:右岸野人数量
        self.bA_m = bA_m #boat A 傳教士的人數
        self.bA_c = bA_c #boat A 野人的人數
        self.bB_m = bB_m #boat B 傳教士的人數
        self.bB_c = bB_c #obat B 野人的人數
        self.bA = bA_pos  # bA:船的位置，右岸: 1 (右 -> 左), 左岸:0 (左 -> 右)
        self.bB = bB_pos  # bB:船的位置，右岸: 1, 左岸:0
        self.bAMove = bA_move # moving: 1
        self.bBMove = bB_move # moving: 1
        self.step = step # step數
        self.cost = cost # 成本
        #self.h = m + c - Ka * ba * ba_move - Kb * bB * bb_move #評估值
        self.parent = parent

def is_safe(right_m, right_c):
    m = right_m
    c = right_c
    leftM = rightM - m
    leftC = rightC - c
    if (m < c and m!= 0): #右岸野人人數不能大於傳教士，除非傳教士為0
        return False
    if (leftM < leftC) and m != rightM: #左岸的野人人數不能大於傳教士，除非左岸傳教士為0
        return False
    if (m < 0 or c < 0): #人數不能小於0
        return False
    if (m == 0 and leftM >= leftC):
        return True
    if (leftM == 0 and m >= c):
        return True
    if m >= c and leftM >= leftC:
        return True

def boatA_actions (bAMax, bAcost, bAtime):
    set_boatA_operation = [] 
    for i in range (bAMax + 1):
        if (i == 0): #船上只有野人
            for j in range(0, bAMax + 1):  
                set_boatA_operation.append([i, j, bAcost, bAtime])
        else: #船上有傳教士
            for j in range (0, i + 1):
                if i + j <= bAMax: 
                    set_boatA_operation.append([i, j, bAcost, bAtime]) 
    print("boatA所有動作為: ", set_boatA_operation)
    return set_boatA_operation

def boatB_actions (bBMax, bBcost, bBtime):
    set_boatB_operation = [] 
    for i in range (bBMax + 1):
        if (i == 0): #船上只有野人
            for j in range(0, bBMax + 1):
                set_boatB_operation.append([i, j, bBcost, bBtime])
        else: #船上有傳教士
            for j in range (0, i + 1):
                if i + j <= bBMax:
                    set_boatB_operation.append([i, j, bBcost, bBtime])
    print("boatB所有動作為: ", set_boatB_operation)
    return set_boatB_operation

boatA_operations = boatA_actions(2, bACost, bATime)
boatB_operations = boatB_actions(3, bBCost, bBTime)


def get_child_by_cost(curr_node, cost_or_time, boatA_operations, boatB_operations):
    successor = []
    right_m = curr_node.m
    right_c = curr_node.c
    left_m = rightM - right_m
    left_c = rightC - right_c  
   
    if (curr_node.bA): 
        for boatA_operation in boatA_operations:
            bA_state = np.array([curr_node.bA, bACost, bATime, 1]) #1: moving
            right_m_bA = right_m - boatA_operation[0] #right_m_bA右岸剩下的傳教士 (右岸原本的傳教士人數 - boatA載的傳教士人數)
            right_c_bA = right_c - boatA_operation[1] #right_c_bA右岸剩下的食人族 (右岸原本的食人族人數 - boatA載的食人族人數)
            if (boatA_operation[0] + boatA_operation[1] == 0):
                bA_state = [-curr_node.bA, 0, 0, 0] #bA_pos, bACost, bATime, bAmove
            if is_safe(right_m_bA, right_c_bA):
                if (curr_node.bB):
                    for boatB_operation in boatB_operations:
                        bB_state = np.array([curr_node.bB, bBCost, bBTime, 1]) #1: moving
                        right_m_bB = right_m_bA -  boatB_operation[0] #right_m_bB右岸剩下的傳教士 (右岸剩下的傳教士人數 - boatB載的傳教士人數)
                        right_c_bB = right_c_bA -  boatB_operation[1] #right_c_bB右岸剩下的食人族 (右岸剩下的食人族人數 - boatB載的食人族人數)
                        if (boatB_operation[0] + boatB_operation[1] == 0):
                                bB_state = [-curr_node.bB, 0, 0, 0] #bB_pos, bBCost, bBTime, bBmove
                                
                        if is_safe(right_m_bB, right_c_bB) and not(bA_state[3] == 0 and bB_state[3] == 0):
                            
                            step = curr_node.step + bA_state[2] + bB_state[2] - min(bA_state[2], bB_state[2]) #原本已經走的step加上boat A, boat B的step 減掉他們重疊的step
                            cost = curr_node.cost + bA_state[1] + bB_state[1]
                            successor.append(Node(right_m_bB, right_c_bB, -bA_state[0], bB_state[3], boatA_operation[0], boatA_operation[1], -bB_state[0], bA_state[3], boatB_operation[0], boatB_operation[1], step, cost, curr_node))
                            print(f"boatA: m {boatA_operation[0]}, c {boatA_operation[1]}")
                            print(f"boatB: m {boatB_operation[0]}, c {boatB_operation[1]}")
                            print(f"右傳 {right_m_bB}, 食 {right_c_bB}, 左傳 {rightM - right_m_bB}, 食 {rightC - right_c_bB}")
                            print(f"cost: {cost}, step: {step}\n")




start_node = Node(rightM, rightC, 1, 0, 0, 0, 1, 0, 0, 0, 0, 0, None)  # 初始狀態節點
get_child_by_cost(start_node, 1, boatA_operations, boatB_operations)
# Out:
# boatA所有動作為:  [[0, 0, 3, 1], [0, 1, 3, 1], [0, 2, 3, 1], [1, 0, 3, 1], [1, 1, 3, 1], [2, 0, 3, 1]]
# boatB所有動作為:  [[0, 0, 25, 1], [0, 1, 25, 1], [0, 2, 25, 1], [0, 3, 25, 1], [1, 0, 25, 1], [1, 1, 25, 1], [2, 0, 25, 1], [2, 1, 25, 1], [3, 0, 25, 1]]
# boatA: m 0, c 0
# boatB: m 0, c 1
# 右傳 3, 食 2, 左傳 0, 食 1
# cost: 25, step: 1
#
# boatA: m 0, c 0
# boatB: m 0, c 2
# 右傳 3, 食 1, 左傳 0, 食 2
# cost: 25, step: 1
#
# boatA: m 0, c 0
# boatB: m 0, c 3
# 右傳 3, 食 0, 左傳 0, 食 3
# cost: 25, step: 1
#
# boatA: m 0, c 0
# boatB: m 1, c 1
# 右傳 2, 食 2, 左傳 1, 食 1
# cost: 25, step: 1
#
# boatA: m 0, c 0
# boatB: m 3, c 0
# 右傳 0, 食 3, 左傳 3, 食 0
# cost: 25, step: 1
#
# boatA: m 0, c 1
# boatB: m 0, c 0
# 右傳 3, 食 2, 左傳 0, 食 1
# cost: 3, step: 1
#
# boatA: m 0, c 1
# boatB: m 0, c 1
# 右傳 3, 食 1, 左傳 0, 食 2
# cost: 28, step: 1
#
# boatA: m 0, c 1
# boatB: m 0, c 2
# 右傳 3, 食 0, 左傳 0, 食 3
# cost: 28, step: 1
#
# boatA: m 0, c 1
# boatB: m 1, c 0
# 右傳 2, 食 2, 左傳 1, 食 1
# cost: 28, step: 1
#
# boatA: m 0, c 1
# boatB: m 2, c 1
# 右傳 1, 食 1, 左傳 2, 食 2
# cost: 28, step: 1
#
# boatA: m 0, c 1
# boatB: m 3, c 0
# 右傳 0, 食 2, 左傳 3, 食 1
# cost: 28, step: 1
#
# boatA: m 0, c 2
# boatB: m 0, c 0
# 右傳 3, 食 1, 左傳 0, 食 2
# cost: 3, step: 1
#
# boatA: m 0, c 2
# boatB: m 0, c 1
# 右傳 3, 食 0, 左傳 0, 食 3
# cost: 28, step: 1
#
# boatA: m 0, c 2
# boatB: m 2, c 0
# 右傳 1, 食 1, 左傳 2, 食 2
# cost: 28, step: 1
#
# boatA: m 0, c 2
# boatB: m 3, c 0
# 右傳 0, 食 1, 左傳 3, 食 2
# cost: 28, step: 1
#
# boatA: m 1, c 1
# boatB: m 0, c 0
# 右傳 2, 食 2, 左傳 1, 食 1
# cost: 3, step: 1
#
# boatA: m 1, c 1
# boatB: m 1, c 1
# 右傳 1, 食 1, 左傳 2, 食 2
# cost: 28, step: 1
#
# boatA: m 1, c 1
# boatB: m 2, c 0
# 右傳 0, 食 2, 左傳 3, 食 1
# cost: 28, step: 1
#
# boatA: m 1, c 1
# boatB: m 2, c 1
# 右傳 0, 食 1, 左傳 3, 食 2
# cost: 28, step: 1

# %%
def uniform_cost_search(goal, start,graph,cost):
    #結果  
    result = []
    #優先權queue
    queue = []
    #將每個點設成最大值
    for i in range(len(goal)):
        result.append(10**8)

    #start插入
    queue.append([0, start])
    opened_list = {}
    count = 0

    while (len(queue) > 0):

        queue = sorted(queue)
        p = queue[-1]

        del queue[-1]

        p[0] *= -1

        if (p[1] in goal):

            index = goal.index(p[1])

            if (result[index] == 10**8):
                count += 1

            if (result[index] > p[0]):
                result[index] = p[0]

            del queue[-1]

            queue = sorted(queue)
            if (count == len(goal)):
                return result

        if (p[1] not in opened_list):
            for i in range(len(graph[p[1]])):

                queue.append( [(p[0] + cost[(p[1], graph[p[1]][i])])* -1, graph[p[1]][i]])

        opened_list[p[1]] = 1

    return result
