# %%
import numpy as np
import prettytable
import logging 
import time
import ipywidgets as widgets
        
class Node:
    def __init__(self, m, c, bA_pos, bA_move, bA_m, bA_c, bB_pos, bB_move, bB_m, bB_c, step, cost, parent, setting, boatSetting):
        self.state = {  'm' : m, 'c' : c, 
                        'bA' : bA_pos, 'bAMove' : bA_move, # bA_pos: boat A's position，right : 1 (right -> left), left:-1 (left -> right)
                        'bB' : bB_pos, 'bBMove' : bB_move } # moving : 1
        
        self.boatA = {'bA_m' : bA_m, 'bA_c' : bA_c} # Missionaries on boat A, cannibals on boat A
        self.boatB = {'bB_m' : bB_m, 'bB_c' : bB_c} # Missionaries on boat B, cannibals on boat B
        
        h = m  + c  - bA_pos * boatSetting['A']['capacity'] * bA_move - bB_pos * boatSetting['B']['capacity'] * bB_move
        if h < 0 or m + c == 0:
            h = 0
        self.h = h
        f = h + step if setting['costOrStep'] else h + cost
        self.data = np.array([cost, step, f])
        # cost: total cost, step: number of steps
        self.parent = parent

def is_safe(right_m, right_c, left_m, left_c, setting):
    m = right_m
    c = right_c
    total_m = right_m + left_m
    total_c = right_c + left_c

    if m < 0 or c < 0 or left_m < 0 or left_c < 0 or total_m != setting['totalM'] or total_c != setting['totalC']: 
        # the number of people cannot be less than 0
        return False

    if m == total_m and c == total_c:
        return False
    
    if (m < c and m!= 0) or ( (left_m < left_c) and left_m != 0): 
        # cannibals <= missionaries  unless missionaries == 0 (right/left bank)
        return False
   
    if (m == 0 and left_m >= left_c) or (left_m == 0 and m >= c) or (m >= c and left_m >= left_c): 
        return True

def boat_actions (id, boatSetting):
    set_boat_operation = [] 
    for i in range (boatSetting[id]['capacity'] + 1):
        if (i == 0): # 船上只有野人
            for j in range(0, boatSetting[id]['capacity'] + 1):  
                set_boat_operation.append([i, j, boatSetting[id]['cost'], boatSetting[id]['step']])

        else: #船上有傳教士
            for j in range (0, i + 1):
                if i + j <= boatSetting[id]['capacity']: 
                    set_boat_operation.append([i, j, boatSetting[id]['cost'], boatSetting[id]['step'] ]) 
    print(f"boat{id} 有{len(set_boat_operation)}種動作，各為: {set_boat_operation}\n")
    return set_boat_operation

def sortNode (dataList, cost_or_step, useAStar):
    
    cost_or_step_or_aStar = 2 if useAStar else cost_or_step
    
    for i in range(len(dataList)):
        for j in range(i, len(dataList)):
            change = 0
            if (dataList[i].data[cost_or_step_or_aStar] < dataList[j].data[cost_or_step_or_aStar]):
                change = 1
            elif (dataList[i].data[cost_or_step_or_aStar] == dataList[j].data[cost_or_step_or_aStar]) and cost_or_step_or_aStar != 0: # 0 cost, 1 step, 2 aStar
                if (dataList[i].data[0] < dataList[j].data[0]):
                    change = 1
                elif (dataList[i].data[0] == dataList[j].data[0]) and dataList[i].data[2] < dataList[j].data[2]:
                    change = 1
            if change:
                temp = dataList[i]
                dataList[i] = dataList[j]
                dataList[j] = temp

def printNode(node, setting): # print node information
    print(f"right bank: m: {node.state['m']}, c: {node.state['c']}")
    print(f"left bank:  m: {setting['totalM'] - node.state['m']}, c: {setting['totalC'] - node.state['c']}")
    print(f"boat A: pos: {node.state['bA']}, move: {node.state['bAMove']}, m: {node.boatA['bA_m']}, c: {node.boatA['bA_c']}")
    print(f"boat B: pos: {node.state['bB']}, move: {node.state['bBMove']}, m: {node.boatB['bB_m']}, c: {node.boatB['bB_c']}")
    print(f"cost: {node.data[0]}, step: {node.data[1]}, h(n): {node.h}, f(n): {node.data[2]}\n")

def get_all_children(curr_node, boatA_operations, boatB_operations, setting, boatSetting, useAStar):
    successor = []
    right_m = curr_node.state['m']
    right_c = curr_node.state['c']
    left_m = setting['totalM'] - right_m
    left_c = setting['totalC'] - right_c 

    for boatA_operation in boatA_operations:

        if (boatA_operation[0] + boatA_operation[1] != 0):
            bA_state = np.array([curr_node.state['bA'], boatSetting['A']['cost'], boatSetting['A']['step'], 1]) # 1: moving
        else:
            bA_state = [-curr_node.state['bA'], 0, 0, 0] # bA_pos, bACost, bATime, bAmove

        if curr_node.state['bA'] > 0: 
            # boat A on the right bank
            boatA_m_to_left = boatA_operation[0]
            boatA_c_to_left = boatA_operation[1]
        else: 
            # boat A on the left bank
            boatA_m_to_left = -boatA_operation[0]
            boatA_c_to_left = -boatA_operation[1]
        
        right_m_bA = right_m - boatA_m_to_left # 右岸剩下的傳教士 = 右岸原本的傳教士人數 -/+ boatA載的傳教士人數
        right_c_bA = right_c - boatA_c_to_left # 右岸剩下的食人族 = 右岸原本的食人族人數 -/+ boatA載的食人族人數
        left_m_bA = left_m + boatA_m_to_left # 左岸剩下的傳教士 (左岸原本的傳教士人數 +/- boatA載的傳教士人數)
        left_c_bA = left_c + boatA_c_to_left # 左岸剩下的食人族 (左岸原本的食人族人數 +/- boatA載的食人族人數)

        if not is_safe(right_m_bA, right_c_bA, left_m_bA, left_c_bA, setting):
            continue
        
        for boatB_operation in boatB_operations:
                    
            if (boatB_operation[0] + boatB_operation[1] != 0):
                bB_state = np.array([curr_node.state['bB'], boatSetting['B']['cost'], boatSetting['B']['step'], 1]) # 1: moving    
            else :
                bB_state = [-curr_node.state['bB'], 0, 0, 0] # bB_pos, bBCost, bBTime, bBmove

            if curr_node.state['bB'] > 0: 
            # boat B on the right bank
                boatB_m_to_left = boatB_operation[0]
                boatB_c_to_left = boatB_operation[1]
            else: 
                # boat B on the left bank
                boatB_m_to_left = -boatB_operation[0]
                boatB_c_to_left = -boatB_operation[1]

            right_m_bB = right_m_bA - boatB_m_to_left # 右岸剩下的傳教士 (右岸剩下的傳教士人數 -/+ boatB載的傳教士人數)
            right_c_bB = right_c_bA - boatB_c_to_left # 右岸剩下的食人族 (右岸剩下的食人族人數 -/+ boatB載的食人族人數)
            left_m_bB = left_m_bA + boatB_m_to_left # 左岸剩下的傳教士 (左岸原本的傳教士人數 +/- boatB載的傳教士人數)
            left_c_bB = left_c_bA + boatB_c_to_left # 左岸剩下的食人族 (左岸原本的食人族人數 +/- boatB載的食人族人數)
            
            if is_safe(right_m_bB, right_c_bB, left_m_bB, left_c_bB, setting) and not(bA_state[3] == 0 and bB_state[3] == 0):
                            
                step = curr_node.data[1] + bA_state[2] + bB_state[2] - min(bA_state[2], bB_state[2]) #原本已經走的step加上boat A, boat B的step 減掉他們重疊的step
                cost = curr_node.data[0] + bA_state[1] + bB_state[1]
                successor.append(Node(right_m_bB, right_c_bB, -bA_state[0], bA_state[3], boatA_operation[0], boatA_operation[1], -bB_state[0], bB_state[3], boatB_operation[0], boatB_operation[1], step, cost, curr_node, setting, boatSetting))
    
    sortNode (successor, setting['costOrStep'], useAStar)
    #for node in successor:
    #    printNode(node, setting)
    return successor

def printTable(dataList, setting):
    table = prettytable.PrettyTable()
    table.field_names = ["step", "left m", "left c", "boatA direction", "boatA [m c]", "boatB direction", "boatB [m c]" , "right m", "right c", "cost", "AStar_h"]

    while dataList:
        node = dataList.pop()
        if (node.state['bA'] == -1 and node.state['bAMove'] == 1):
            boatA_direction = "L <- R"
        elif(node.state['bA'] == -1 and node.state['bAMove'] == 0):
            boatA_direction = "L (X)"
        elif (node.state['bA'] == 1 and node.state['bAMove'] == 1):
            boatA_direction = "L -> R"
        else :
            boatA_direction = "R (X)"

        if (node.state['bB'] == -1 and node.state['bBMove'] == 1):
            boatB_direction = "L <- R"
        elif(node.state['bB'] == -1 and node.state['bBMove'] == 0):
            boatB_direction = "L (X)"
        elif (node.state['bB'] == 1 and node.state['bBMove'] == 1):
            boatB_direction = "L -> R"
        else :
            boatB_direction = "R (X)"

        table.add_row([ node.data[1], setting['totalM'] - node.state['m'], setting['totalC'] - node.state['c'], 
                        boatA_direction, list(node.boatA.values()), boatB_direction, list(node.boatB.values()), 
                        node.state['m'], node.state['c'], node.data[0], node.h])
    with open('table.txt', 'a') as w:
        w.write(str(table))    
    #print(table)

def logging_file(open_list, close_list):
    logging.basicConfig(filename= "basic.log", level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

    logging.info('********open list********, len = {}'.format(len(open_list)))
    for open_data in open_list:
        logging.debug('{}\n> cost = {}, step = {}, f(n) = {}\n> {}\n> {}'.format(   open_data.state,
                                                                                    open_data.data[0], open_data.data[1], open_data.data[2], 
                                                                                    open_data.boatA, open_data.boatB))
    logging.info('********close list********, len = {}'.format(len(close_list)))
    for close_data in close_list:
        logging.debug('{}\n> cost = {}, step = {}, f(n) = {}\n> {}\n> {}'.format(   close_data.state,
                                                                                    close_data.data[0], close_data.data[1], close_data.data[2], 
                                                                                    close_data.boatA, close_data.boatB))
    logging.info('--------------------------------------------------------------------------------------------------------')

def calculate_path(curr_node):
    result = []
    result.append(curr_node)
    parent_node = curr_node.parent
    while (parent_node):
        result.append(parent_node)
        parent_node = parent_node.parent
    return result


def uniform_cost_search(goal, start_node, setting, boatSetting):
    open_list = []
    close_list = []
    open_list.append(start_node)
    useAStar = 0
    count_open = 1
    count_close = 0

    while True:
        if not open_list:
            print ("no solution!!!")

            print(f"count_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")

            with open('table.txt', 'a') as w:
                w.write(f"\ncount_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")
            break
        
        curr_node = open_list.pop()

        if (curr_node.state['m'] == goal[0] and curr_node.state['c'] == goal[1] ):
            result = calculate_path(curr_node)
            printTable(result, setting)
            print(f"count_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")

            with open('table.txt', 'a') as w:
                w.write(f"\ncount_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")

            break

        close_list.append(curr_node)
        count_close = count_close + 1
        children = get_all_children(curr_node, boatA_operations, boatB_operations, setting, boatSetting, useAStar) # cost: 0 , time: 1
        
        for child in children:
            sameNode_in_open_list = 0
            sameNode_in_close_list = 0
            
            for i in range(len(close_list)):
                if np.array_equal(child.state, close_list[i].state): #and np.array_equal(child.data, close_list[i].data):
                    sameNode_in_close_list = 1
                    break
            
            for j in range(len(open_list)):
                if np.array_equal(child.state, open_list[j].state):
                    sameNode_in_open_list = 1
                    if child.data[ setting['costOrStep'] ] < open_list[j].data[ setting['costOrStep'] ]:
                        open_list.pop(j)
                    break
            
            if (sameNode_in_close_list != 1 and sameNode_in_open_list != 1):
                open_list.append(child)
                count_open =  1 + count_open
        sortNode(open_list, setting['costOrStep'], useAStar)
        #logging_file(open_list, close_list)

def AStar_algorithm(goal, start_node, setting, boatSetting):
    open_list = []
    close_list = []
    open_list.append(start_node)
    useAStar = 1
    count_open = 1
    count_close = 0

    while True:
        if not open_list:
            print ("no solution!!!")
            print(f"count_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")
            with open('table.txt', 'a') as w:
                w.write(f"\ncount_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")
            break
        
        curr_node = open_list.pop()
        
        if (curr_node.state['m'] == goal[0] and curr_node.state['c'] == goal[1] ):
            result = calculate_path(curr_node)
            printTable(result, setting)
            print(f"count_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")

            with open('table.txt', 'a') as w:
                w.write(f"\ncount_open: {count_open}, count_close: {count_close}, open+close: {count_open + count_close}")
            break

        close_list.append(curr_node)
        count_close = count_close + 1
        children = get_all_children(curr_node, boatA_operations, boatB_operations, setting, boatSetting, useAStar) 

        for child in children:
            sameNode_in_open_list = 0
            sameNode_in_close_list = 0

            for i in range(len(open_list)):
                if np.array_equal(child.state, open_list[i].state):
                    if child.data[2] < open_list[i].data[2]: # beter => remove older, append newer, AStar_f
                        open_list.pop(i)
                    else : # newer no better
                        sameNode_in_open_list = 1
                    break

            if (sameNode_in_open_list != 1):
                for j in range(len(close_list)):
                    if np.array_equal(child.state, close_list[j].state):
                        if child.data[2] < close_list[j].data[2]: # beter => remove older, append newer, AStar_f
                            close_list.pop(j)
                        else : # newer no better
                            sameNode_in_close_list = 1
                        break

                if (sameNode_in_close_list != 1):
                    open_list.append(child)
                    count_open =  1 + count_open

        sortNode(open_list, setting['costOrStep'], useAStar)
        #logging_file(open_list, close_list)

boatSetting = dict()
boatSetting['A'] = { 'capacity': 2, 'cost': 3,  'step' : 1, 'pos' : 1} # pos : right bank: 1, left bank: -1
boatSetting['B'] = { 'capacity': 3, 'cost': 25, 'step' : 1, 'pos' : 1}
setting = {'totalM': 7, 'totalC' : 7, 'costOrStep' : 1}

boatA_operations = boat_actions('A', boatSetting)
boatB_operations = boat_actions('B', boatSetting)

with open('table.txt', 'a+', encoding='utf-8') as w:
    w.truncate(0)

for m in range(3): #3
    for n in range (3, 11): #3, 11
        
        for i in range (2):
            setting = {'totalM': m+n, 'totalC' : n, 'costOrStep' : i}
            start_node = Node(m + n, n, 1, 0, 0, 0, 1, 0, 0, 0, 0, 0, None, setting, boatSetting) # 初始狀態節點
            goal_node = [0, 0]

            with open('table.txt', 'a') as w:
                w.write(f"******************\ntotalM: {m+n}, totalC: {n}, costOrStep: {i}\n")

            print(f"Astar  totalM: {m+n}, totalC: {n}, costOrStep: {i}")
            start_time = time.time()
            AStar_algorithm (goal_node, start_node, setting, boatSetting)
            end_time = time.time()
            with open('table.txt', 'a') as w:
                w.write(f", AStar exe time : { round(end_time - start_time, 3)}\n\n")
                print(f"exe time : { round(end_time - start_time, 3)}\n")
            
            print(f"UCS!!  totalM: {m+n}, totalC: {n}, costOrStep: {i}")
            start_time = time.time()
            uniform_cost_search(goal_node, start_node, setting, boatSetting)
            end_time = time.time()
            with open('table.txt', 'a') as w:
                w.write(f", UCS exe time: { round(end_time - start_time, 3)}\n\n")
                print(f"exe time: { round(end_time - start_time, 3)}\n")
# Out:
# boatA 有6種動作，各為: [[0, 0, 3, 1], [0, 1, 3, 1], [0, 2, 3, 1], [1, 0, 3, 1], [1, 1, 3, 1], [2, 0, 3, 1]]
#
# boatB 有9種動作，各為: [[0, 0, 25, 1], [0, 1, 25, 1], [0, 2, 25, 1], [0, 3, 25, 1], [1, 0, 25, 1], [1, 1, 25, 1], [2, 0, 25, 1], [2, 1, 25, 1], [3, 0, 25, 1]]
#
# Astar  totalM: 3, totalC: 3, costOrStep: 0
# count_open: 75, count_close: 22, open+close: 97
# exe time : 0.027
#
# UCS!!  totalM: 3, totalC: 3, costOrStep: 0
# count_open: 78, count_close: 42, open+close: 120
# exe time: 0.06
#
# Astar  totalM: 3, totalC: 3, costOrStep: 1
# count_open: 26, count_close: 3, open+close: 29
# exe time : 0.003
#
# UCS!!  totalM: 3, totalC: 3, costOrStep: 1
# count_open: 75, count_close: 44, open+close: 119
# exe time: 0.073
#
# Astar  totalM: 4, totalC: 4, costOrStep: 0
# count_open: 95, count_close: 57, open+close: 152
# exe time : 0.066
#
# UCS!!  totalM: 4, totalC: 4, costOrStep: 0
# count_open: 95, count_close: 61, open+close: 156
# exe time: 0.1
#
# Astar  totalM: 4, totalC: 4, costOrStep: 1
# count_open: 47, count_close: 8, open+close: 55
# exe time : 0.008
#
# UCS!!  totalM: 4, totalC: 4, costOrStep: 1
# count_open: 104, count_close: 81, open+close: 185
# exe time: 0.144
#
# Astar  totalM: 5, totalC: 5, costOrStep: 0
# count_open: 112, count_close: 72, open+close: 184
# exe time : 0.085
#
# UCS!!  totalM: 5, totalC: 5, costOrStep: 0
# count_open: 112, count_close: 79, open+close: 191
# exe time: 0.132
#
# Astar  totalM: 5, totalC: 5, costOrStep: 1
# count_open: 72, count_close: 22, open+close: 94
# exe time : 0.031
#
# UCS!!  totalM: 5, totalC: 5, costOrStep: 1
# count_open: 126, count_close: 105, open+close: 231
# exe time: 0.203
#
# Astar  totalM: 6, totalC: 6, costOrStep: 0
# count_open: 140, count_close: 111, open+close: 251
# exe time : 0.144
#
# UCS!!  totalM: 6, totalC: 6, costOrStep: 0
# count_open: 140, count_close: 112, open+close: 252
# exe time: 0.2
#
# Astar  totalM: 6, totalC: 6, costOrStep: 1
# count_open: 120, count_close: 59, open+close: 179
# exe time : 0.099
#
# UCS!!  totalM: 6, totalC: 6, costOrStep: 1
# count_open: 165, count_close: 133, open+close: 298
# exe time: 0.33
#
# Astar  totalM: 7, totalC: 7, costOrStep: 0
# no solution!!!
# count_open: 109, count_close: 109, open+close: 218
# exe time : 0.145
#
# UCS!!  totalM: 7, totalC: 7, costOrStep: 0
# no solution!!!
# count_open: 109, count_close: 109, open+close: 218
# exe time: 0.182
#
# Astar  totalM: 7, totalC: 7, costOrStep: 1
# no solution!!!
# count_open: 174, count_close: 152, open+close: 326
# exe time : 0.269
#
# UCS!!  totalM: 7, totalC: 7, costOrStep: 1
# no solution!!!
# count_open: 109, count_close: 109, open+close: 218
# exe time: 0.21
#
# Astar  totalM: 8, totalC: 8, costOrStep: 0
# no solution!!!
# count_open: 121, count_close: 121, open+close: 242
# exe time : 0.193
#
# UCS!!  totalM: 8, totalC: 8, costOrStep: 0
# no solution!!!
# count_open: 121, count_close: 121, open+close: 242
# exe time: 0.26
#
# Astar  totalM: 8, totalC: 8, costOrStep: 1
# no solution!!!
# count_open: 195, count_close: 171, open+close: 366
# exe time : 0.357
#
# UCS!!  totalM: 8, totalC: 8, costOrStep: 1
# no solution!!!
# count_open: 121, count_close: 121, open+close: 242
# exe time: 0.34
#
# Astar  totalM: 9, totalC: 9, costOrStep: 0
# no solution!!!
# count_open: 133, count_close: 133, open+close: 266
# exe time : 0.297
#
# UCS!!  totalM: 9, totalC: 9, costOrStep: 0
# no solution!!!
# count_open: 133, count_close: 133, open+close: 266
# exe time: 0.315
#
# Astar  totalM: 9, totalC: 9, costOrStep: 1
# no solution!!!
# count_open: 216, count_close: 192, open+close: 408
# exe time : 0.504
#
# UCS!!  totalM: 9, totalC: 9, costOrStep: 1
# no solution!!!
# count_open: 133, count_close: 133, open+close: 266
# exe time: 0.329
#
# Astar  totalM: 10, totalC: 10, costOrStep: 0
# no solution!!!
# count_open: 145, count_close: 145, open+close: 290
# exe time : 0.307
#
# UCS!!  totalM: 10, totalC: 10, costOrStep: 0
# no solution!!!
# count_open: 145, count_close: 145, open+close: 290
# exe time: 0.414
#
# Astar  totalM: 10, totalC: 10, costOrStep: 1
# no solution!!!
# count_open: 241, count_close: 216, open+close: 457
# exe time : 0.623
#
# UCS!!  totalM: 10, totalC: 10, costOrStep: 1
# no solution!!!
# count_open: 145, count_close: 145, open+close: 290
# exe time: 0.421
#
# Astar  totalM: 4, totalC: 3, costOrStep: 0
# count_open: 98, count_close: 26, open+close: 124
# exe time : 0.047
#
# UCS!!  totalM: 4, totalC: 3, costOrStep: 0
# count_open: 109, count_close: 56, open+close: 165
# exe time: 0.137
#
# Astar  totalM: 4, totalC: 3, costOrStep: 1
# count_open: 68, count_close: 8, open+close: 76
# exe time : 0.02
#
# UCS!!  totalM: 4, totalC: 3, costOrStep: 1
# count_open: 109, count_close: 88, open+close: 197
# exe time: 0.279
#
# Astar  totalM: 5, totalC: 4, costOrStep: 0
# count_open: 152, count_close: 85, open+close: 237
# exe time : 0.241
#
# UCS!!  totalM: 5, totalC: 4, costOrStep: 0
# count_open: 152, count_close: 91, open+close: 243
# exe time: 0.309
#
# Astar  totalM: 5, totalC: 4, costOrStep: 1
# count_open: 72, count_close: 10, open+close: 82
# exe time : 0.027
#
# UCS!!  totalM: 5, totalC: 4, costOrStep: 1
# count_open: 160, count_close: 135, open+close: 295
# exe time: 0.56
#
# Astar  totalM: 6, totalC: 5, costOrStep: 0
# count_open: 197, count_close: 111, open+close: 308
# exe time : 0.372
#
# UCS!!  totalM: 6, totalC: 5, costOrStep: 0
# count_open: 197, count_close: 137, open+close: 334
# exe time: 0.7
#
# Astar  totalM: 6, totalC: 5, costOrStep: 1
# count_open: 95, count_close: 15, open+close: 110
# exe time : 0.041
#
# UCS!!  totalM: 6, totalC: 5, costOrStep: 1
# count_open: 195, count_close: 162, open+close: 357
# exe time: 0.81
#
# Astar  totalM: 7, totalC: 6, costOrStep: 0
# count_open: 237, count_close: 168, open+close: 405
# exe time : 0.689
#
# UCS!!  totalM: 7, totalC: 6, costOrStep: 0
# count_open: 239, count_close: 182, open+close: 421
# exe time: 0.899
#
# Astar  totalM: 7, totalC: 6, costOrStep: 1
# count_open: 130, count_close: 20, open+close: 150
# exe time : 0.073
#
# UCS!!  totalM: 7, totalC: 6, costOrStep: 1
# count_open: 249, count_close: 220, open+close: 469
# exe time: 1.237
#
# Astar  totalM: 8, totalC: 7, costOrStep: 0
# count_open: 276, count_close: 207, open+close: 483
# exe time : 0.813
#
# UCS!!  totalM: 8, totalC: 7, costOrStep: 0
# count_open: 279, count_close: 218, open+close: 497
# exe time: 1.206
#
# Astar  totalM: 8, totalC: 7, costOrStep: 1
# count_open: 153, count_close: 45, open+close: 198
# exe time : 0.178
#
# UCS!!  totalM: 8, totalC: 7, costOrStep: 1
# count_open: 297, count_close: 263, open+close: 560
# exe time: 1.637
#
# Astar  totalM: 9, totalC: 8, costOrStep: 0
# count_open: 314, count_close: 243, open+close: 557
# exe time : 1.008
#
# UCS!!  totalM: 9, totalC: 8, costOrStep: 0
# count_open: 320, count_close: 255, open+close: 575
# exe time: 1.64
#
# Astar  totalM: 9, totalC: 8, costOrStep: 1
# count_open: 165, count_close: 47, open+close: 212
# exe time : 0.188
#
# UCS!!  totalM: 9, totalC: 8, costOrStep: 1
# count_open: 336, count_close: 297, open+close: 633
# exe time: 2.199
#
# Astar  totalM: 10, totalC: 9, costOrStep: 0
# count_open: 350, count_close: 279, open+close: 629
# exe time : 1.271
#
# UCS!!  totalM: 10, totalC: 9, costOrStep: 0
# count_open: 356, count_close: 290, open+close: 646
# exe time: 2.003
#
# Astar  totalM: 10, totalC: 9, costOrStep: 1
# count_open: 204, count_close: 55, open+close: 259
# exe time : 0.245
#
# UCS!!  totalM: 10, totalC: 9, costOrStep: 1
# count_open: 375, count_close: 322, open+close: 697
# exe time: 2.307
#
# Astar  totalM: 11, totalC: 10, costOrStep: 0
# count_open: 386, count_close: 315, open+close: 701
# exe time : 1.647
#
# UCS!!  totalM: 11, totalC: 10, costOrStep: 0
# count_open: 392, count_close: 326, open+close: 718
# exe time: 2.495
#
# Astar  totalM: 11, totalC: 10, costOrStep: 1
# count_open: 226, count_close: 80, open+close: 306
# exe time : 0.452
#
# UCS!!  totalM: 11, totalC: 10, costOrStep: 1
# count_open: 421, count_close: 371, open+close: 792
# exe time: 3.165
#
# Astar  totalM: 5, totalC: 3, costOrStep: 0
# count_open: 154, count_close: 75, open+close: 229
# exe time : 0.248
#
# UCS!!  totalM: 5, totalC: 3, costOrStep: 0
# count_open: 154, count_close: 92, open+close: 246
# exe time: 0.451
#
# Astar  totalM: 5, totalC: 3, costOrStep: 1
# count_open: 60, count_close: 5, open+close: 65
# exe time : 0.015
#
# UCS!!  totalM: 5, totalC: 3, costOrStep: 1
# count_open: 152, count_close: 115, open+close: 267
# exe time: 0.66
#
# Astar  totalM: 6, totalC: 4, costOrStep: 0
# count_open: 208, count_close: 120, open+close: 328
# exe time : 0.49
#
# UCS!!  totalM: 6, totalC: 4, costOrStep: 0
# count_open: 208, count_close: 126, open+close: 334
# exe time: 0.786
#
# Astar  totalM: 6, totalC: 4, costOrStep: 1
# count_open: 124, count_close: 18, open+close: 142
# exe time : 0.09
#
# UCS!!  totalM: 6, totalC: 4, costOrStep: 1
# count_open: 214, count_close: 190, open+close: 404
# exe time: 1.425
#
# Astar  totalM: 7, totalC: 5, costOrStep: 0
# count_open: 265, count_close: 175, open+close: 440
# exe time : 0.954
#
# UCS!!  totalM: 7, totalC: 5, costOrStep: 0
# count_open: 265, count_close: 203, open+close: 468
# exe time: 1.599
#
# Astar  totalM: 7, totalC: 5, costOrStep: 1
# count_open: 125, count_close: 20, open+close: 145
# exe time : 0.108
#
# UCS!!  totalM: 7, totalC: 5, costOrStep: 1
# count_open: 275, count_close: 250, open+close: 525
# exe time: 2.207
#
# Astar  totalM: 8, totalC: 6, costOrStep: 0
# count_open: 317, count_close: 236, open+close: 553
# exe time : 1.485
#
# UCS!!  totalM: 8, totalC: 6, costOrStep: 0
# count_open: 321, count_close: 252, open+close: 573
# exe time: 2.324
#
# Astar  totalM: 8, totalC: 6, costOrStep: 1
# count_open: 145, count_close: 22, open+close: 167
# exe time : 0.13
#
# UCS!!  totalM: 8, totalC: 6, costOrStep: 1
# count_open: 322, count_close: 284, open+close: 606
# exe time: 3.062
#
# Astar  totalM: 9, totalC: 7, costOrStep: 0
# count_open: 368, count_close: 284, open+close: 652
# exe time : 1.961
#
# UCS!!  totalM: 9, totalC: 7, costOrStep: 0
# count_open: 373, count_close: 300, open+close: 673
# exe time: 3.266
#
# Astar  totalM: 9, totalC: 7, costOrStep: 1
# count_open: 203, count_close: 35, open+close: 238
# exe time : 0.273
#
# UCS!!  totalM: 9, totalC: 7, costOrStep: 1
# count_open: 391, count_close: 360, open+close: 751
# exe time: 4.413
#
# Astar  totalM: 10, totalC: 8, costOrStep: 0
# count_open: 418, count_close: 332, open+close: 750
# exe time : 2.509
#
# UCS!!  totalM: 10, totalC: 8, costOrStep: 0
# count_open: 422, count_close: 347, open+close: 769
# exe time: 4.094
#
# Astar  totalM: 10, totalC: 8, costOrStep: 1
# count_open: 202, count_close: 37, open+close: 239
# exe time : 0.29
#
# UCS!!  totalM: 10, totalC: 8, costOrStep: 1
# count_open: 452, count_close: 416, open+close: 868
# exe time: 5.575
#
# Astar  totalM: 11, totalC: 9, costOrStep: 0
# count_open: 466, count_close: 380, open+close: 846
# exe time : 3.009
#
# UCS!!  totalM: 11, totalC: 9, costOrStep: 0
# count_open: 472, count_close: 395, open+close: 867
# exe time: 5.45
#
# Astar  totalM: 11, totalC: 9, costOrStep: 1
# count_open: 222, count_close: 39, open+close: 261
# exe time : 0.312
#
# UCS!!  totalM: 11, totalC: 9, costOrStep: 1
# count_open: 493, count_close: 441, open+close: 934
# exe time: 6.245
#
# Astar  totalM: 12, totalC: 10, costOrStep: 0
# count_open: 514, count_close: 428, open+close: 942
# exe time : 3.642
#
# UCS!!  totalM: 12, totalC: 10, costOrStep: 0
# count_open: 520, count_close: 443, open+close: 963
# exe time: 6.31
#
# Astar  totalM: 12, totalC: 10, costOrStep: 1
# count_open: 280, count_close: 52, open+close: 332
# exe time : 0.585
#
# UCS!!  totalM: 12, totalC: 10, costOrStep: 1
# count_open: 552, count_close: 510, open+close: 1062
# exe time: 8.639
